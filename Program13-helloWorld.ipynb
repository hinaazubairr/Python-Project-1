# %% [markdown]
# Write some text as normal

# %% [markdown]
# # Title
# ## Smaller Title
# ### even smaller Title
# Some text
#
# *text*
#
# **bold**
#
# $$x_{i}$$

# %%
print("hello world")
# Out:
# hello world

# %%
x=10
y=15

# %%
print(x)
# Out:
# 10

# %%
print(y)
# Out:
# 15

# %%
import numpy as np

# %% [markdown]
# $$x$$

# %% [markdown]
# $$x_{i}$$

# %% [markdown]
# $$x_{1}$$

# %% [markdown]
# $$[\dots]$$

# %% [markdown]
# $$\in$$

# %% [markdown]
# $$\{0,1\}$$

# %% [markdown]
# $$w = [w_{1}, w_{2}, \dots, w_{n}]; w_{i} \in \{-1,0,1\}$$

# %% [markdown]
# $$\{-1,0,1\}$$

# %% [markdown]
# $$\hat{y} $$

# %% [markdown]
# $$\hat{y} = x \cdot w \geq \theta$$

# %%
a = np.array ([0,1,2])
b = np.array ([3,4,5])

# %%
# the 1st two arguments of the dor function are the 2 arrays we would like to multiply together.
# we will add array a as the 1st argument and array b as the 2nd argument
# the result of the function will be 14
print(np.dot(a,b))
# i.e. (0*3)+(1*4)+(2*5)=0+4+10=14
# Out:
# 14

# %%
x = np.array([ 1, 0 ])
w = np.array([ 1, 1 ]) # Listen to both input

# %%
neuron_output = np.dot( x, w )
print(neuron_output)
# (1*1)+(0*1)=1+0=1
# Out:
# 1
